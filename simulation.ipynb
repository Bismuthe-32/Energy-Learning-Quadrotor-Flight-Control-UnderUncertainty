# %% [markdown]
# <a href="https://colab.research.google.com/github/Bismuthe-32/Energy-Learning-Quadrotor-Flight-Control-UnderUncertainty/blob/main/simulation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # State Space Model
#
# We simulate a rigid-body nonlinear-system
#
# ## State vector $x$
#
# $$
# x = \begin{bmatrix} \
# p \\
# v \\
# q \\
# ω \\
# \end{bmatrix}
# $$
#
# $p$ is position in x,y,z: $p \in \mathbb{R}^3$\
# $v$ is linear velocity: $v \in \mathbb{R}^3$\
# $q$ is quaternion orientation: $q \in \mathbb{R}^4$\
# $\omega$ is angular velocity: $\omega \in \mathbb{R}^3$

# %%
m = 1.2
g = 9.81
L = 0.25

I = np.diag([0.02, 0.02, 0.04])

kf = 1e-5
km = 2e-6

dt = 0.002
